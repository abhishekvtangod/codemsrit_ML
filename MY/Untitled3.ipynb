# %%
import pandas as pd
import numpy as np
import math

# %%
df=pd.read_csv('/home/sfs1721/Desktop/ML 03.05.19/MLworkshop/Mall_Customers.csv')
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# 5             6  Female   22                  17                      76
# 6             7  Female   35                  18                       6
# 7             8  Female   23                  18                      94
# 8             9    Male   64                  19                       3
# 9            10  Female   30                  19                      72
# 10           11    Male   67                  19                      14
# 11           12  Female   35                  19                      99
# ...

# %% [markdown]
# df.isnull().sum()

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %% [raw]
# print(df.shape[1])

# %%
from sklearn.model_selection import train_test_split
labels=df['Spending Score (1-100)']
df_train=df.drop(['Spending Score (1-100)'],axis=1)
x_train,x_test,y_train,y_test=train_test_split(df_train,labels,test_size=0.2)

# %%
x_train()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-50b56435184a> in <module>
# ----> 1 x_train()
#
# TypeError: 'DataFrame' object is not callable

# %%
x_train
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)
# 171         172    Male   28                  87
# 26           27  Female   45                  28
# 77           78    Male   40                  54
# 31           32  Female   21                  30
# 35           36  Female   21                  33
# 145         146    Male   28                  77
# 37           38  Female   30                  34
# 53           54    Male   59                  43
# 69           70  Female   32                  48
# 14           15    Male   37                  20
# 110         111    Male   65                  63
# 2             3  Female   20                  16
# 128         129    Male   59                  71
# 91           92    Male   18                  59
# 34           35  Female   49                  33
# 49           50  Female   31                  40
# 94           95  Female   32                  60
# 63           64  Female   54                  47
# ...

# %%
y_train
# Out:
# 171    75
# 26     32
# 77     48
# 31     73
# 35     81
# 145    97
# 37     73
# 53     60
# 69     47
# 14     13
# 110    52
# 2       6
# 128    11
# 91     41
# 34     14
# 49     42
# 94     42
# 63     59
# 141    93
# 115    50
# 162     5
# 41     92
# 102    59
# 134     5
# 176    15
# 107    46
# 114    48
# 89     46
# 142    40
# 121    40
#        ..
# 156     1
# 25     82
# 149    90
# 78     52
# 165    75
# 167    95
# 163    93
# 57     46
# 18     29
# 130     9
# 133    71
# 97     50
# 51     60
# 170    13
# 5      76
# 75     54
# 96     47
# 8       3
# 59     46
# 70     55
# 132    34
# 1      81
# 146    36
# 29     87
# 131    75
# 60     56
# 144    12
# 191    69
# 92     49
# 88     60
# Name: Spending Score (1-100), Length: 160, dtype: int64

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
x_test
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)
# 83           84  Female   46                  54
# 6             7  Female   35                  18
# 85           86    Male   48                  54
# 45           46  Female   24                  39
# 86           87  Female   55                  57
# 9            10  Female   30                  19
# 150         151    Male   43                  78
# 192         193    Male   33                 113
# 126         127    Male   43                  71
# 38           39  Female   36                  37
# 193         194  Female   38                 113
# 137         138    Male   32                  73
# 68           69    Male   19                  48
# 138         139    Male   19                  74
# 50           51  Female   49                  42
# 90           91  Female   68                  59
# 3             4  Female   23                  16
# 197         198    Male   32                 126
# ...

# %%
import pandas as pd

# %%
training=pd.get_dummies(, columns=["Gender"])
#training.drop('Sex_female', axis=1, )

# %%
training
# Out:
#      CustomerID  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1   19                  15                      39
# 1             2   21                  15                      81
# 2             3   20                  16                       6
# 3             4   23                  16                      77
# 4             5   31                  17                      40
# 5             6   22                  17                      76
# 6             7   35                  18                       6
# 7             8   23                  18                      94
# 8             9   64                  19                       3
# 9            10   30                  19                      72
# 10           11   67                  19                      14
# 11           12   35                  19                      99
# 12           13   58                  20                      15
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-95433c5ddce4> in <module>
# ----> 1 training.drop('Gender', axis=1, inplace=True)
#       2 training
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
training.drop('M_F',axis=1,inplace=True)

# %%
training['M_F']=np.where(training['Age']=="Male", 1, 0)

# %%
training
# Out:
#      CustomerID  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1   19                  15                      39
# 1             2   21                  15                      81
# 2             3   20                  16                       6
# 3             4   23                  16                      77
# 4             5   31                  17                      40
# 5             6   22                  17                      76
# 6             7   35                  18                       6
# 7             8   23                  18                      94
# 8             9   64                  19                       3
# 9            10   30                  19                      72
# 10           11   67                  19                      14
# 11           12   35                  19                      99
# 12           13   58                  20                      15
# ...

# %%
training
# Out:
#      CustomerID  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1   19                  15                      39
# 1             2   21                  15                      81
# 2             3   20                  16                       6
# 3             4   23                  16                      77
# 4             5   31                  17                      40
# 5             6   22                  17                      76
# 6             7   35                  18                       6
# 7             8   23                  18                      94
# 8             9   64                  19                       3
# 9            10   30                  19                      72
# 10           11   67                  19                      14
# 11           12   35                  19                      99
# 12           13   58                  20                      15
# ...

# %%
from sklearn.model_selection import train_test_split
labels=training['Spending Score (1-100)']
train_data=training.drop(['Spending Score (1-100)'],axis=1)
x_train,x_test,y_train,y_test=train_test_split(train_data,labels,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
prediction=model.predict(x_test)
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
x_train
